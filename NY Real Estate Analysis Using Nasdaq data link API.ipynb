# %%
#pip install nasdaq-data-link
# Out:
# Requirement already satisfied: nasdaq-data-link in p:\anaconda\lib\site-packages (1.0.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: six in p:\anaconda\lib\site-packages (from nasdaq-data-link) (1.15.0)
# Requirement already satisfied: pandas>=0.14 in p:\anaconda\lib\site-packages (from nasdaq-data-link) (1.0.5)
# Requirement already satisfied: numpy>=1.8 in p:\anaconda\lib\site-packages (from nasdaq-data-link) (1.18.5)
# Requirement already satisfied: requests>=2.7.0 in p:\anaconda\lib\site-packages (from nasdaq-data-link) (2.24.0)
# Requirement already satisfied: inflection>=0.3.1 in p:\anaconda\lib\site-packages (from nasdaq-data-link) (0.5.1)
# Requirement already satisfied: more-itertools in p:\anaconda\lib\site-packages (from nasdaq-data-link) (8.4.0)
# Requirement already satisfied: python-dateutil in p:\anaconda\lib\site-packages (from nasdaq-data-link) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in p:\anaconda\lib\site-packages (from pandas>=0.14->nasdaq-data-link) (2020.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in p:\anaconda\lib\site-packages (from requests>=2.7.0->nasdaq-data-link) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in p:\anaconda\lib\site-packages (from requests>=2.7.0->nasdaq-data-link) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in p:\anaconda\lib\site-packages (from requests>=2.7.0->nasdaq-data-link) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in p:\anaconda\lib\site-packages (from requests>=2.7.0->nasdaq-data-link) (2.10)

# %%
import pandas as pd
import numpy as np

#Data source
#import quandl
import nasdaqdatalink

#Data viz
import plotly.graph_objs as go

# %% [markdown]
# # New York Real Estate Market Analysis

# %% [markdown]
# In this project I use the Nasdaq-data-link API to access Zillow real estate data. I analyze the data provided by the API and create several visuals that clearly represent the data. I use this API to specifically examine the market values of several types of homes in New York from 1996 to 2022.

# %% [markdown]
# ### API

# %%
key_api = 'Nnqe96L2tR12Du5-iSWy'

# %%
# connection with quandl datavase
#quandl.ApiConfig.api_key = key_api
nasdaqdatalink.ApiConfig.api_key = key_api

# %% [markdown]
# ### Query Data

# %%
#start = pd.to_datetime('2012-01-01')
#end = pd.to_datetime('2021-05-25')

# %%
## County Region codes
#Queens_County = 1347
#Bronx_County = 401
#Suffolk_County = 3148
#Nassau_County = 2046
#Westchester_County = 1252

# %% [markdown]
# ### 3 bedroom Homes Market Value data from 1996 - 2021 in several NY counties

# %%
# requesting data from Nasdaq-data link API by indicator and region specifications
#midtown = nasdaqdatalink.get('ZILLOW/N466_MRPST',start_date=start,end_date=end)
#harlem = nasdaqdatalink.get('ZILLOW/N27_MRPST',start_date=start,end_date=end)
queens = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z3BR', region_id='1347')
bronx = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z3BR', region_id='401')
westchester = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z3BR', region_id='3148')
suffolk = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z3BR', region_id='2046')
nassau =  nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z3BR', region_id='1252')

# %%
queens
# Out:
#      indicator_id region_id       date     value
# None
# 0            Z3BR     62120 2021-07-31  560009.0
# 1            Z3BR     62120 2021-06-30  555364.0
# 2            Z3BR     62120 2021-05-31  550810.0
# 3            Z3BR     62120 2021-04-30  543589.0
# 4            Z3BR     62120 2021-03-31  540966.0
# ...           ...       ...        ...       ...
# 302          Z3BR     62120 1996-05-31  170250.0
# 303          Z3BR     62120 1996-04-30  171048.0
# 304          Z3BR     62120 1996-03-31  172806.0
# 305          Z3BR     62120 1996-02-29  173618.0
# 306          Z3BR     62120 1996-01-31  175010.0
#
# [307 rows x 4 columns]

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=queens.date, y=queens.value, name = 'NY Queens'))
graph.add_trace(go.Scatter(x=bronx.date, y=bronx.value, name = 'NY Bronx'))
graph.add_trace(go.Scatter(x=suffolk.date, y=suffolk.value, name = 'NY Suffolk'))
graph.add_trace(go.Scatter(x=westchester.date, y=westchester.value, name = 'NY Westchester'))
graph.add_trace(go.Scatter(x=nassau.date, y=nassau.value, name = 'NY Nassau'))
graph.update_layout(title="Average 3 Bedroom Home Value in NY Counties")
graph.update_xaxes(rangeslider_visible=True, title = 'Slider above')
graph.show()
# Out:
# <div>                            <div id="60875755-971f-4d2b-baf7-1ac0d176bbbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60875755-971f-4d2b-baf7-1ac0d176bbbf")) {                    Plotly.newPlot(                        "60875755-971f-4d2b-baf7-1ac0d176bbbf",                        [{"name":"NY Queens","x":["2021-07-31T00:00:00","2021-06-30T00:00:00","2021-05-31T00:00:00","2021-04-30T00:00:00","2021-03-31T00:00:00","2021-02-28T00:00:00","2021-01-31T00:00:00","2020-12-31T00:00:00","2020-11-30T00:00:00","2020-10-31T00:00:00","2020-09-30T00:00:00","2020-08-31T00:00:00","2020-07-31T00:00:00","2020-06-30T00:00:00","2020-05-31T00:00:00","2020-04-30T00:00:00","2020-03-31T00:00:00","2020-02-29T00:00:00","2020-01-31T00:00:00","2019-12-31T00:00:00","2019-11-30T00:00:00","2019-10-31T00:00:00","2019-09-30T00:00:00","2019-08-31T00:00:00","2019-07-31T00:00:00","2019-06-30T00:00:00","2019-05-31T00:00:00","2019-04-30T00:00:00","2019-03-31T00:00:00","2019-02-28T00:00:00","2019-01-31T00:00:00","2018-12-31T00:00:00","2018-11-30T00:00:00","2018-10-31T00:00:00","2018-09-30T00:00:00","2018-08-31T00:00:00","2018-07-31T00:00:00","2018-06-30T00:00:00","2018-05-31T00:00:00","2018-04-30T00:00:00","2018-03-31T00:00:00","2018-02-28T00:00:00","2018-01-31T00:00:00","2017-12-31T00:00:00","2017-11-30T00:00:00","2017-10-31T00:00:00","2017-09-30T00:00:00","2017-08-31T00:00:00","2017-07-31T00:00:00","2017-06-30T00:00:00","2017-05-31T00:00:00","2017-04-30T00:00:00","2017-03-31T00:00:00","2017-02-28T00:00:00","2017-01-31T00:00:00","2016-12-31T00:00:00","2016-11-30T00:00:00","2016-10-31T00:00:00","2016-09-30T00:00:00","2016-08-31T00:00:00","2016-07-31T00:00:00","2016-06-30T00:00:00","2016-05-31T00:00:00","2016-04-30T00:00:00","2016-03-31T00:00:00","2016-02-29T00:00:00","2016-01-31T00:00:00","2015-12-31T00:00:00","2015-11-30T00:00:00","2015-10-31T00:00:00","2015-09-30T00:00:00","2015-08-31T00:00:00","2015-07-31T00:00:00","2015-06-30T00:00:00","2015-05-31T00:00:00","2015-04-30T00:00:00","2015-03-31T00:00:00","2015-02-28T00:00:00","2015-01-31T00:00:00","2014-12-31T00:00:00","2014-11-30T00:00:00","2014-10-31T00:00:00","2014-09-30T00:00:00","2014-08-31T00:00:00","2014-07-31T00:00:00","2014-06-30T00:00:00","2014-05-31T00:00:00","2014-04-30T00:00:00","2014-03-31T00:00:00","2014-02-28T00:00:00","2014-01-31T00:00:00","2013-12-31T00:00:00","2013-11-30T00:00:00","2013-10-31T00:00:00","2013-09-30T00:00:00","2013-08-31T00:00:00","2013-07-31T00:00:00","2013-06-30T00:00:00","2013-05-31T00:00:00","2013-04-30T00:00:00","2013-03-31T00:00:00","2013-02-28T00:00:00","2013-01-31T00:00:00","2012-12-31T00:00:00","2012-11-30T00:00:00","2012-10-31T00:00:00","2012-09-30T00:00:00","2012-08-31T00:00:00","2012-07-31T00:00:00","2012-06-30T00:00:00","2012-05-31T00:00:00","2012-04-30T00:00:00","2012-03-31T00:00:00","2012-02-29T00:00:00","2012-01-31T00:00:00","2011-12-31T00:00:00","2011-11-30T00:00:00","2011-10-31T00:00:00","2011-09-30T00:00:00","2011-08-31T00:00:00","2011-07-31T00:00:00","2011-06-30T00:00:00","2011-05-31T00:00:00","2011-04-30T00:00:00","2011-03-31T00:00:00","2011-02-28T00:00:00","2011-01-31T00:00:00","2010-12-31T00:00:00","2010-11-30T00:00:00","2010-10-31T00:00:00","2010-09-30T00:00:00","2010-08-31T00:00:00","2010-07-31T00:00:00","2010-06-30T00:00:00","2010-05-31T00:00:00","2010-04-30T00:00:00","2010-03-31T00:00:00","2010-02-28T00:00:00","2010-01-31T00:00:00","2009-12-31T00:00:00","2009-11-30T00:00:00","2009-10-31T00:00:00","2009-09-30T00:00:00","2009-08-31T00:00:00","2009-07-31T00:00:00","2009-06-30T00:00:00","2009-05-31T00:00:00","2009-04-30T00:00:00","2009-03-31T00:00:00","2009-02-28T00:00:00","2009-01-31T00:00:00","2008-12-31T00:00:00","2008-11-30T00:00:00","2008-10-31T00:00:00","2008-09-30T00:00:00","2008-08-31T00:00:00","2008-07-31T ...

# %%
## indicators
# condos - ZCON
# single family homes - ZSFH
# 5+ bedroom homes - Z5BR
# For-Sale Inventory (Raw, All Homes, Monthly) - IRAM

# %% [markdown]
# ### 5+ bedroom Homes Market Value data from 1996 - 2021 in several NY counties

# %%
queens = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z5BR', region_id='62120')
bronx = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z5BR', region_id='401')
westchester = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z5BR', region_id='3148')
suffolk = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z5BR', region_id='2046')
nassau =  nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='Z5BR', region_id='1252')

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=queens.date, y=queens.value, name = 'NY Queens'))
graph.add_trace(go.Scatter(x=bronx.date, y=bronx.value, name = 'NY Bronx'))
graph.add_trace(go.Scatter(x=suffolk.date, y=suffolk.value, name = 'NY Suffolk'))
graph.add_trace(go.Scatter(x=westchester.date, y=westchester.value, name = 'NY Westchester'))
graph.add_trace(go.Scatter(x=nassau.date, y=nassau.value, name = 'NY Nassau'))
graph.update_layout(title="Average 5+ Bedroom Home Value in NY Counties")
graph.update_xaxes(rangeslider_visible=True, title = 'Slider above')
graph.show()
# Out:
# <div>                            <div id="867e25d8-3bb8-4f48-915b-55b2fb0a990e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
T00:00:00","2012-04-30T00:00:00","2012-03-31T00:00:00","2012-02-29T00:00:00","2012-01-31T00:00:00","2011-12-31T00:00:00","2011-11-30T00:00:00","2011-10-31T00:00:00","2011-09-30T00:00:00","2011-08-31T00:00:00","2011-07-31T00:00:00","2011-06-30T00:00:00","2011-05-31T00:00:00","2011-04-30T00:00:00","2011-03-31T00:00:00","2011-02-28T00:00:00","2011-01-31T00:00:00","2010-12-31T00:00:00","2010-11-30T00:00:00","2010-10-31T00:00:00","2010-09-30T00:00:00","2010-08-31T00:00:00","2010-07-31T00:00:00","2010-06-30T00:00:00","2010-05-31T00:00:00","2010-04-30T00:00:00","2010-03-31T00:00:00","2010-02-28T00:00:00","2010-01-31T00:00:00","2009-12-31T00:00:00","2009-11-30T00:00:00","2009-10-31T00:00:00","2009-09-30T00:00:00","2009-08-31T00:00:00","2009-07-31T00:00:00","2009-06-30T00:00:00","2009-05-31T00:00:00","2009-04-30T00:00:00","2009-03-31T00:00:00","2009-02-28T00:00:00","2009-01-31T00:00:00","2008-12-31T00:00:00","2008-11-30T00:00:00","2008-10-31T00:00:00","2008-09-30T00:00:00","2008-08-31T00:00:00","2008-07-31T ...

# %% [markdown]
# ### Condominiums Market Value Data from 1996 - 2021 in several NY Counties

# %%
queens = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZCON', region_id='1347')
bronx = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZCON', region_id='401')
westchester = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZCON', region_id='3148')
suffolk = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZCON', region_id='2046')
nassau =  nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZCON', region_id='1252')

# %%
queens.head()
# Out:
#      indicator_id region_id       date     value
# None
# 0            ZCON      1347 2021-07-31  357661.0
# 1            ZCON      1347 2021-06-30  355743.0
# 2            ZCON      1347 2021-05-31  354825.0
# 3            ZCON      1347 2021-04-30  354534.0
# 4            ZCON      1347 2021-03-31  354936.0

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=queens.date, y=queens.value, name = 'NY Queens'))
graph.add_trace(go.Scatter(x=bronx.date, y=bronx.value, name = 'NY Bronx'))
graph.add_trace(go.Scatter(x=suffolk.date, y=suffolk.value, name = 'NY Suffolk'))
graph.add_trace(go.Scatter(x=westchester.date, y=westchester.value, name = 'NY Westchester'))
graph.add_trace(go.Scatter(x=nassau.date, y=nassau.value, name = 'NY Nassau'))
graph.update_layout(title="Average Condominium Market Value in NY Counties")
graph.update_xaxes(rangeslider_visible=True, title = 'Slider above')
graph.show()
# Out:
# <div>                            <div id="b2509eed-32e4-4376-8ace-682f6e9a26f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2509eed-32e4-4376-8ace-682f6e9a26f0")) {                    Plotly.newPlot(                        "b2509eed-32e4-4376-8ace-682f6e9a26f0",                        [{"name":"NY Queens","x":["2021-07-31T00:00:00","2021-06-30T00:00:00","2021-05-31T00:00:00","2021-04-30T00:00:00","2021-03-31T00:00:00","2021-02-28T00:00:00","2021-01-31T00:00:00","2020-12-31T00:00:00","2020-11-30T00:00:00","2020-10-31T00:00:00","2020-09-30T00:00:00","2020-08-31T00:00:00","2020-07-31T00:00:00","2020-06-30T00:00:00","2020-05-31T00:00:00","2020-04-30T00:00:00","2020-03-31T00:00:00","2020-02
00:00","2010-02-28T00:00:00","2010-01-31T00:00:00","2009-12-31T00:00:00","2009-11-30T00:00:00","2009-10-31T00:00:00","2009-09-30T00:00:00","2009-08-31T00:00:00","2009-07-31T00:00:00","2009-06-30T00:00:00","2009-05-31T00:00:00","2009-04-30T00:00:00","2009-03-31T00:00:00","2009-02-28T00:00:00","2009-01-31T00:00:00","2008-12-31T00:00:00","2008-11-30T00:00:00","2008-10-31T00:00:00","2008-09-30T00:00:00","2008-08-31T00:00:00","2008-07-31T ...

# %% [markdown]
# ### Top-Tier Homes Market Value Data from 1996 - 2021 in several NY Counties

# %%
queens = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZATT', region_id='1347')
bronx = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZATT', region_id='401')
westchester = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZATT', region_id='3148')
suffolk = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZATT', region_id='2046')
nassau =  nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZATT', region_id='1252')

# %%
queens.head()
# Out:
#      indicator_id region_id       date     value
# None
# 0            ZATT      1347 2021-07-31  862879.0
# 1            ZATT      1347 2021-06-30  859662.0
# 2            ZATT      1347 2021-05-31  856060.0
# 3            ZATT      1347 2021-04-30  852945.0
# 4            ZATT      1347 2021-03-31  850939.0

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=queens.date, y=queens.value, name = 'NY Queens'))
graph.add_trace(go.Scatter(x=bronx.date, y=bronx.value, name = 'NY Bronx'))
graph.add_trace(go.Scatter(x=suffolk.date, y=suffolk.value, name = 'NY Suffolk'))
graph.add_trace(go.Scatter(x=westchester.date, y=westchester.value, name = 'NY Westchester'))
graph.add_trace(go.Scatter(x=nassau.date, y=nassau.value, name = 'NY Nassau'))
graph.update_layout(title="Average Top-Tier Homes Market Value in NY Counties")
graph.update_xaxes(rangeslider_visible=True, title = 'Slider above')
graph.show()
# Out:
# <div>                            <div id="e08bcd57-faa1-4d9a-aa3a-f265f0176469" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e08bcd57-faa1-4d9a-aa3a-f265f0176469")) {                    Plotly.newPlot(                        "e08bcd57-faa1-4d9a-aa3a-f265f0176469",                        [{"name":"NY Queens","x":["2021-07-31T00:00:00","2021-06-30T00:00:00","2021-05-31T00:00:00","2021-04-30T00:00:00","2021-03-31T00:00:00","2021-02-28T00:00:00","2021-01-31T00:00:00","2020-12-31T00:00:00","2020-11-30T00:00:00","2020-10-31T00:00:00","2020-09-30T00:00:00","2020-08-31T00:00:00","2020-07-31T00:00:00","2020-06-30T00:00:00","2020-05-31T00:00:00","2020-04-30T00:00:00","2020-03-31T00:00:00","2020-02-29T00:00:00","2020-01-31T00:00:00","2019-12-31T00:00:00","2019-11-30T00:00:00","2019-10-31T00:00:00","2019-09-30T00:00:00","2019-08-31T00:00:00","2019-07-31T00:00:00","2019-06-30T00:00:00","2019-05-31T00:00:00","2019-04-30T00:00:00","2019-03-31T00:00:00","2019-02-28T00:00:00","2019-01-31T00:00:00","2018-12-31T00:00:00","2018-11-30T00:00:00","2018-10-31T00:00:00","2018-09-30T00:00:00","2018-08-31T00:00:00","2018-07-31T00:00:00","2018-06-30T00:00:00","2018-05-31T00:00:00","2018-04-30T00:00:00","2018-